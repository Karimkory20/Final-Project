# %%
from google.colab import files

# Upload file manually
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e929904f-9322-4526-95c2-1e9b67251c50" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e929904f-9322-4526-95c2-1e9b67251c50">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cyber.csv", encoding='latin-1', delimiter=',', on_bad_lines='skip')

# %%
print(df.columns)
# Out:
# Index(['AttackDate;Country;Spam;Ransomware;Local Infection;Exploit;Malicious Mail;Network Attack;On Demand Scan;Web Threat;Total_Attack_Percentage;Rank Spam;Rank Ransomware;Rank Local Infection;Rank Exploit;Rank Malicious Mail;Rank Network Attack;Rank On Demand Scan;Rank Web Threat'], dtype='object')

# %%
df
# Out:
#       AttackDate;Country;Spam;Ransomware;Local Infection;Exploit;Malicious Mail;Network Attack;On Demand Scan;Web Threat;Total_Attack_Percentage;Rank Spam;Rank Ransomware;Rank Local Infection;Rank Exploit;Rank Malicious Mail;Rank Network Attack;Rank On Demand Scan;Rank Web Threat
# 0      2022-10-11 00:00:00;Arab Republic of Egypt;0.0...
# 1      2022-10-11 00:00:00;Argentine Republic;0.00601...
# 2      2022-10-11 00:00:00;Aruba;;;0.01384;;0.00092;;...
# 3      2022-10-11 00:00:00;Bailiwick of Guernsey;;;0....
# 4      2022-10-11 00:00:00;Bailiwick of Jersey;0.0000...
# ...                                                  ...
# 77226  2023-12-11 00:00:00;United Arab Emirates;0.000...
# 77227  2023-12-11 00:00:00;United Kingdom of Great Br...
# 77228  2023-12-11 00:00:00;United Mexican States;0.00...
# 77229  2023-12-11 00:00:00;United Republic of Tanzani...
# 77230  2023-12-11 00:00:00;United States of America;0...
#
# [77231 rows x 1 columns]

# %%
df = pd.read_csv('cyber.csv', sep=';', encoding='latin-1')
# or 'ISO-8859-1', or any other encoding that might be appropriate for your file.

# %%
df
# Out:
#                 AttackDate                                            Country  \
# 0      2022-10-11 00:00:00                             Arab Republic of Egypt
# 1      2022-10-11 00:00:00                                 Argentine Republic
# 2      2022-10-11 00:00:00                                              Aruba
# 3      2022-10-11 00:00:00                              Bailiwick of Guernsey
# 4      2022-10-11 00:00:00                                Bailiwick of Jersey
# ...                    ...                                                ...
# 77618  2023-12-11 00:00:00                               United Arab Emirates
# 77619  2023-12-11 00:00:00  United Kingdom of Great Britain and Northern I...
# 77620  2023-12-11 00:00:00                              United Mexican States
# 77621  2023-12-11 00:00:00                        United Republic of Tanzania
# 77622  2023-12-11 00:00:00                           United States of America
#
# ...

# %%
df['AttackDate'] = pd.to_datetime(df['AttackDate'], format='%Y-%m-%d %H:%M:%S')

# %%
print(df.head())
# Out:
#   AttackDate                 Country     Spam  Ransomware  Local Infection  \
# 0 2022-10-11  Arab Republic of Egypt  0.00090     0.00013          0.01353
# 1 2022-10-11      Argentine Republic  0.00601     0.00006          0.00575
# 2 2022-10-11                   Aruba      NaN         NaN          0.01384
# 3 2022-10-11   Bailiwick of Guernsey      NaN         NaN          0.00546
# 4 2022-10-11     Bailiwick of Jersey  0.00003         NaN          0.00774
#
#    Exploit  Malicious Mail  Network Attack  On Demand Scan  Web Threat  \
# 0  0.00013         0.00287         0.01007         0.01148     0.01708
# 1  0.00035         0.00058         0.00095         0.00482     0.00974
# 2      NaN         0.00092             NaN         0.00830     0.00554
# 3  0.00273             NaN         0.00091         0.00546     0.01001
# 4  0.00101         0.00067             NaN         0.00707     0.01145
#
#    Total_Attack_Percentage  Rank Spam  Rank Ransomware  Rank Local Infection  \
# ...

# %%
df
# Out:
#       AttackDate                                            Country     Spam  \
# 0     2022-10-11                             Arab Republic of Egypt  0.00090
# 1     2022-10-11                                 Argentine Republic  0.00601
# 2     2022-10-11                                              Aruba      NaN
# 3     2022-10-11                              Bailiwick of Guernsey      NaN
# 4     2022-10-11                                Bailiwick of Jersey  0.00003
# ...          ...                                                ...      ...
# 77618 2023-12-11                               United Arab Emirates  0.00064
# 77619 2023-12-11  United Kingdom of Great Britain and Northern I...  0.01292
# 77620 2023-12-11                              United Mexican States  0.00500
# 77621 2023-12-11                        United Republic of Tanzania  0.00030
# 77622 2023-12-11                           United States of America  0.21790
#
# ...

# %%
print(df['Spam'].isnull().sum())  # Count missing values
# Out:
# 14641

# %%
df['Spam'].fillna(df['Spam'].mean(), inplace=True)  # Replace with mean
# Out:
# <ipython-input-24-6f19c1df1ef9>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Spam'].fillna(df['Spam'].mean(), inplace=True)  # Replace with mean

# %%
df
# Out:
#       AttackDate                                            Country      Spam  \
# 0     2022-10-11                             Arab Republic of Egypt  0.000900
# 1     2022-10-11                                 Argentine Republic  0.006010
# 2     2022-10-11                                              Aruba  0.006094
# 3     2022-10-11                              Bailiwick of Guernsey  0.006094
# 4     2022-10-11                                Bailiwick of Jersey  0.000030
# ...          ...                                                ...       ...
# 77618 2023-12-11                               United Arab Emirates  0.000640
# 77619 2023-12-11  United Kingdom of Great Britain and Northern I...  0.012920
# 77620 2023-12-11                              United Mexican States  0.005000
# 77621 2023-12-11                        United Republic of Tanzania  0.000300
# 77622 2023-12-11                           United States of America  0.217900
#
# ...

# %%
print(df['Ransomware'].isnull().sum())  # Count missing values
# Out:
# 25479

# %%
df['Ransomware'].fillna(0, inplace=True)
# Out:
# <ipython-input-27-48fe46e60800>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Ransomware'].fillna(0, inplace=True)

# %%
print(df['Local Infection'].isnull().sum())  # Count missing values
# Out:
# 3154

# %%
df['Local Infection'].fillna(0, inplace=True)
# Out:
# <ipython-input-29-c1c791aff686>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Local Infection'].fillna(0, inplace=True)

# %%
df
# Out:
#       AttackDate                                            Country      Spam  \
# 0     2022-10-11                             Arab Republic of Egypt  0.000900
# 1     2022-10-11                                 Argentine Republic  0.006010
# 2     2022-10-11                                              Aruba  0.006094
# 3     2022-10-11                              Bailiwick of Guernsey  0.006094
# 4     2022-10-11                                Bailiwick of Jersey  0.000030
# ...          ...                                                ...       ...
# 77618 2023-12-11                               United Arab Emirates  0.000640
# 77619 2023-12-11  United Kingdom of Great Britain and Northern I...  0.012920
# 77620 2023-12-11                              United Mexican States  0.005000
# 77621 2023-12-11                        United Republic of Tanzania  0.000300
# 77622 2023-12-11                           United States of America  0.217900
#
# ...

# %%
print(df['Exploit'].isnull().sum())  # Count missing values
# Out:
# 13359

# %%
df['Exploit'].fillna(0, inplace=True)
# Out:
# <ipython-input-32-8f8f75d8f816>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Exploit'].fillna(0, inplace=True)

# %%
print(df['Malicious Mail'].isnull().sum())  # Count missing values
# Out:
# 8439

# %%
df['Malicious Mail'].fillna(0, inplace=True)
# Out:
# <ipython-input-35-a812375bb152>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Malicious Mail'].fillna(0, inplace=True)

# %%
print(df['Network Attack'].isnull().sum())  # Count missing values
# Out:
# 6091

# %%
df['Network Attack'].fillna(df['Network Attack'].mean(), inplace=True)
# Out:
# <ipython-input-37-bfe3a899efc3>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Network Attack'].fillna(df['Network Attack'].mean(), inplace=True)

# %%
print(df['On Demand Scan'].isnull().sum())  # Count missing values
# Out:
# 3392

# %%
print(df['Web Threat'].isnull().sum())  # Count missing values
# Out:
# 3731

# %%
print(df['Rank Spam'].isnull().sum())  # Count missing values
# Out:
# 0

# %%
df
# Out:
#       AttackDate                                            Country      Spam  \
# 0     2022-10-11                             Arab Republic of Egypt  0.000900
# 1     2022-10-11                                 Argentine Republic  0.006010
# 2     2022-10-11                                              Aruba  0.006094
# 3     2022-10-11                              Bailiwick of Guernsey  0.006094
# 4     2022-10-11                                Bailiwick of Jersey  0.000030
# ...          ...                                                ...       ...
# 77618 2023-12-11                               United Arab Emirates  0.000640
# 77619 2023-12-11  United Kingdom of Great Britain and Northern I...  0.012920
# 77620 2023-12-11                              United Mexican States  0.005000
# 77621 2023-12-11                        United Republic of Tanzania  0.000300
# 77622 2023-12-11                           United States of America  0.217900
#
# ...

# %%
df['Web Threat'].fillna(0, inplace=True)
# Out:
# <ipython-input-42-3640d5c76317>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Web Threat'].fillna(0, inplace=True)

# %%
df['Total_Attack_Percentage'].fillna(df['Total_Attack_Percentage'].mean(), inplace=True)
# Out:
# <ipython-input-43-8b20d1127c12>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Total_Attack_Percentage'].fillna(df['Total_Attack_Percentage'].mean(), inplace=True)

# %%
df['On Demand Scan'].fillna(0, inplace=True)
# Out:
# <ipython-input-39-8790c755cdf4>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['On Demand Scan'].fillna(0, inplace=True)

# %%
df
# Out:
#       AttackDate                                            Country      Spam  \
# 0     2022-10-11                             Arab Republic of Egypt  0.000900
# 1     2022-10-11                                 Argentine Republic  0.006010
# 2     2022-10-11                                              Aruba  0.006094
# 3     2022-10-11                              Bailiwick of Guernsey  0.006094
# 4     2022-10-11                                Bailiwick of Jersey  0.000030
# ...          ...                                                ...       ...
# 77618 2023-12-11                               United Arab Emirates  0.000640
# 77619 2023-12-11  United Kingdom of Great Britain and Northern I...  0.012920
# 77620 2023-12-11                              United Mexican States  0.005000
# 77621 2023-12-11                        United Republic of Tanzania  0.000300
# 77622 2023-12-11                           United States of America  0.217900
#
# ...

# %%
print(df['Rank Ransomware'].isnull().sum())  # Count missing values
# Out:
# 0

# %%
print(df['Web Threat'].isnull().sum())  # Count missing values

# %%
print(df['Rank Local Infection'].isnull().sum())  # Count missing values
# Out:
# 0

# %%
print(df['Rank Exploit'].isnull().sum())  # Count missing values
# Out:
# 0

# %%
print(df['Rank Malicious Mail'].isnull().sum())  # Count missing values
# Out:
# 0

# %%
print(df['Rank Network Attack'].isnull().sum())  # Count missing values
# Out:
# 0

# %%
print(df['Rank On Demand Scan'].isnull().sum())  # Count missing values
# Out:
# 0

# %%
print(df['Rank Web Threat'].isnull().sum())  # Count missing values
# Out:
# 0

# %%
df['Total_Attack_Percentage'] = df['Total_Attack_Percentage'] * 100
df['Total_Attack_Percentage'] = df['Total_Attack_Percentage'].map(lambda x: f"{x:.2f}%")

# %%
df
# Out:
#       AttackDate                                            Country      Spam  \
# 0     2022-10-11                             Arab Republic of Egypt  0.000900
# 1     2022-10-11                                 Argentine Republic  0.006010
# 2     2022-10-11                                              Aruba  0.006094
# 3     2022-10-11                              Bailiwick of Guernsey  0.006094
# 4     2022-10-11                                Bailiwick of Jersey  0.000030
# ...          ...                                                ...       ...
# 77618 2023-12-11                               United Arab Emirates  0.000640
# 77619 2023-12-11  United Kingdom of Great Britain and Northern I...  0.012920
# 77620 2023-12-11                              United Mexican States  0.005000
# 77621 2023-12-11                        United Republic of Tanzania  0.000300
# 77622 2023-12-11                           United States of America  0.217900
#
# ...

# %%
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [AttackDate, Country, Spam, Ransomware, Local Infection, Exploit, Malicious Mail, Network Attack, On Demand Scan, Web Threat, Total_Attack_Percentage, Rank Spam, Rank Ransomware, Rank Local Infection, Rank Exploit, Rank Malicious Mail, Rank Network Attack, Rank On Demand Scan, Rank Web Threat]
# Index: []

# %%
duplicate_count = df.duplicated().sum()
print(f"Total duplicate rows: {duplicate_count}")
# Out:
# Total duplicate rows: 0

# %%
# Save cleaned dataset
df.to_csv('formatted_cyber.csv', index=False)

# %%
from google.colab import files
files.download("formatted_cyber.csv") # Changed filename to match the saved file
